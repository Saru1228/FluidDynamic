# %% [markdown]
# ## 2.1 wave function

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# $\frac{\partial q}{\partial t} + c \frac{\partial q}{\partial x} = 0 (c>0)$

# %% [markdown]
# $q = f(x-ct)$

# %% [markdown]
# ## 2.2 Solution of wave function

# %% [markdown]
# ### FTCS method

# %% [markdown]
# Forward in time
#
# $\frac{\partial q}{\partial t} = \frac{q_j^{n+1} - q_j^{n}}{\Delta t}$

# %% [markdown]
# Centered in space
#
# $\frac{\partial q}{\partial x} = \frac{q_{j+1}^n - q_{j-1}^n}{2\Delta x}$

# %% [markdown]
# ### Programming and figure 1

# %%
#Initialization of const number

c = 1
dt = 0.05
dx = 0.1
jmax = 21
nmax = 6
x = np.linspace(0,dx*(jmax -1),jmax)

q = np.zeros(jmax)
for j in range(jmax):
    if (j < jmax /2):
        q[j] = 1
    else:
        q[j] = 0

# %%
plt.figure(figsize=(7,7),dpi=100)
plt.rcParams["font.size"] = 22

plt.plot(x,q,marker="o",lw=2,label="n=0")

for n in range(1,nmax+1):
    qold =q.copy()
    for j in range(1,jmax-1):
        q[j] = qold[j]-dt *c*(qold[j+1]-qold[j-1])/(2 * dx)
    if n % 2 ==0:
        plt.plot(x,q,marker="o",lw=2,label=f'n={n}')

plt.grid(color="black",linestyle="dashed",linewidth=0.5)
plt.xlim([0,2.0])
plt.xlabel("x")
plt.ylabel("q")
plt.legend()
plt.show()

# %% [markdown]
# ### 风上差分 Upwind Scheme

# %% [markdown]
# backward in space
#
# $\frac{\partial q}{\partial x} = \frac{q_{j}^n - q_{j-1}^n}{\Delta x}$

# %% [markdown]
# CFL condition:
# $v = c \frac{\Delta t}{\Delta x} \le 1$

# %% [markdown]
# ### Programming and figure 2

# %%
#Initialization of const number

c = 1
dt = 0.05
dx = 0.1
jmax = 21
nmax = 6
x = np.linspace(0,dx*(jmax -1),jmax)

q = np.zeros(jmax)
for j in range(jmax):
    if (j < jmax /2):
        q[j] = 1
    else:
        q[j] = 0

# %%
plt.figure(figsize=(7,7),dpi=100)
plt.rcParams["font.size"] = 22

plt.plot(x,q,marker="o",lw=2,label="n=0")

for n in range(1,nmax+1):
    qold =q.copy()
    for j in range(1,jmax-1):
        q[j] = qold[j]-dt *c*(qold[j]-qold[j-1])/(dx)
    if n % 2 ==0:
        plt.plot(x,q,marker="o",lw=2,label=f'n={n}')

plt.grid(color="black",linestyle="dashed",linewidth=0.5)
plt.xlim([0,2.0])
plt.ylim([0,1.2])
plt.xlabel("x")
plt.ylabel("q")
plt.legend()
plt.show()

# %% [markdown]
# ### 风下差分 downwind Scheme

# %% [markdown]
# forward in space
#
# $\frac{\partial q}{\partial x} = \frac{q_{j+1}^n - q_{j}^n}{\Delta x}$

# %% [markdown]
# ### Programmingn and figure 3

# %%
#Initialization of const number

c = 1
dt = 0.05
dx = 0.1
jmax = 21
nmax = 6
x = np.linspace(0,dx*(jmax -1),jmax)

q = np.zeros(jmax)
for j in range(jmax):
    if (j < jmax /2):
        q[j] = 1
    else:
        q[j] = 0

# %%
plt.figure(figsize=(7,7),dpi=100)
plt.rcParams["font.size"] = 22

plt.plot(x,q,marker="o",lw=2,label="n=0")

for n in range(1,nmax+1):
    qold =q.copy()
    for j in range(1,jmax-1):
        q[j] = qold[j]-dt *c*(qold[j+1]-qold[j])/(dx)
    if n % 2 ==0:
        plt.plot(x,q,marker="o",lw=2,label=f'n={n}')

plt.grid(color="black",linestyle="dashed",linewidth=0.5)
plt.xlim([0,2.0])
plt.xlabel("x")
plt.ylabel("q")
plt.legend()
plt.show()

# %% [markdown]
# ### Lax Method

# %% [markdown]
# Main method: Average first part

# %% [markdown]
# $q_j^{n+1} = 1/2 (q_{j+1}^n +q_{j-1}^n) - c/2 \frac{\Delta t}{\Delta x} (q_{j+1}^n-q_{j-1}^n)$

# %% [markdown]
# ### Programming and figure 4

# %%
#Initialization of const number

c = 1
dt = 0.05
dx = 0.1
jmax = 21
nmax = 6
x = np.linspace(0,dx*(jmax -1),jmax)

q = np.zeros(jmax)
for j in range(jmax):
    if (j < jmax /2):
        q[j] = 1
    else:
        q[j] = 0

# %%
plt.figure(figsize=(7,7),dpi=100)
plt.rcParams["font.size"] = 22

plt.plot(x,q,marker="o",lw=2,label="n=0")

for n in range(1,nmax+1):
    qold =q.copy()
    for j in range(1,jmax-1):
        q[j] = 0.5 * (qold[j+1]+qold[j-1]) - dt *c*(qold[j+1]-qold[j-1])/(2 * dx)
    if n % 2 ==0:
        plt.plot(x,q,marker="o",lw=2,label=f'n={n}')

plt.grid(color="black",linestyle="dashed",linewidth=0.5)
plt.xlim([0,2.0])
plt.xlabel("x")
plt.ylabel("q")
plt.legend()
plt.show()

# %% [markdown]
# ### Lax-Wendroff Method

# %% [markdown]
# $q_j^{n+1} = q_j^n - \frac{c}{2} \frac{\Delta t}{\Delta x}(q_{j+1}^n +q_{j-1}^n) + \frac{c^2}{2} \frac{\Delta t}{\Delta x} (q_{j+1}^n-2q_j^n + q_{j-1}^n)$

# %% [markdown]
# ### Programming and figure 5

# %%
#Initialization of const number

c = 1
dt = 0.05
dx = 0.1
jmax = 21
nmax = 6
x = np.linspace(0,dx*(jmax -1),jmax)

q = np.zeros(jmax)
for j in range(jmax):
    if (j < jmax /2):
        q[j] = 1
    else:
        q[j] = 0

# %%
plt.figure(figsize=(7,7),dpi=100)
plt.rcParams["font.size"] = 22

plt.plot(x,q,marker="o",lw=2,label="n=0")

for n in range(1,nmax+1):
    qold =q.copy()
    for j in range(1,jmax-1):
        q[j] = qold[j] - c / 2 * dt / dx * (qold[j+1]-qold[j-1]) + c**2 /2 * dt / dx * (q[j+1] - 2 * q[j] + q[j-1])
    if n % 2 ==0:
        plt.plot(x,q,marker="o",lw=2,label=f'n={n}')

plt.grid(color="black",linestyle="dashed",linewidth=0.5)
plt.xlabel("x")
plt.ylabel("q")
plt.legend()
plt.title("Lax-Wendroff Result")
plt.show()

# %% [markdown]
# ## 2.3 Linear problems with an undetermined sign of the advection velocity

# %% [markdown]
# c > 0 :
#
# $q_j^{n+1} = q_j^n - \Delta \cdot c \frac{q_j^n - q_{j-1}^n}{\Delta x}$

# %% [markdown]
# c < 0:
#
# $q_j^{n+1} = q_j^n - \Delta \cdot c \frac{q_{j+1}^n - q_{j}^n}{\Delta x}$

# %%
def Calculate(x,q,c,dt,nmax,dx):
    plt.figure(figsize=(7,7),dpi=100)
    plt.rcParams["font.size"] = 22
    plt.plot(x,q,marker="o",lw=2,label="n=0")

    for n in range (1, nmax +1):
        qold = q.copy()
        for j in range(1,jmax -1):
            c2 = 0.5 * (c + abs(c))
            c3 = 0.5 * (c -abs(c))
            q[j] = qold[j] - dt * ((c2 * (qold[j]-qold[j-1])/dx) + (c3 * (qold[j+1]-qold[j])/dx))
        
        if n %2 ==0:
            plt.plot(x,q,marker="o",lw=2,label=f'n={n}')
    plt.grid(color="black",linestyle="dashed",linewidth=0.5)
    plt.xlabel("x")
    plt.ylabel("q")
    plt.legend()
    plt.title("Upwind Result")
    plt.show()

# %%
c = 1
dt = 0.05
dx = 0.1
jmax = 21
nmax = 6
x = np.linspace(0,dx*(jmax -1),jmax)

q = np.zeros(jmax)
for j in range(jmax):
    if (j < jmax /2):
        q[j] = 1
    else:
        q[j] = 0

# %%
Calculate(x,q,c,dt,nmax,dx)

# %%
c = - 1
dt = 0.05
dx = 0.1
jmax = 21
nmax = 6
x = np.linspace(0,dx*(jmax -1),jmax)

q = np.zeros(jmax)
for j in range(jmax):
    if (j < jmax /2):
        q[j] = 1
    else:
        q[j] = 0

# %%
Calculate(x,q,c,dt,nmax,dx)

# %% [markdown]
# ## 2.4 Numerical flux

# %% [markdown]
# We start from :
#
# $\frac{\partial q}{\partial t} + \frac{\partial f}{\partial x} = 0$
#
# In fluid mechanics, $f$ is referred to as the flux.

# %% [markdown]
# Thus :
#
# $q_{j}^{n+1} = q_{j}^{n} - \frac{\Delta t}{\Delta x} (\hat{f}_{j + \frac{1}{2}}^n -\hat{f}_{j - \frac{1}{2}}^n)$

# %% [markdown]
# #### Review of Scalar Advection Equation in FLUX

# %% [markdown]
# FTCS method :
#
# $\hat{f}_{j+\frac{1}{2}}^n = \frac{\hat{f}_{j+1}^n + \hat{f}_{j}^n}{2}$

# %% [markdown]
# Upwind scheme
#
# $\hat{f}_{j+\frac{1}{2}}^n =\hat{f}_{j}^n$

# %% [markdown]
# Lax method:
#
# $\hat{f}_{j+\frac{1}{2}}^n =\frac{1}{2} \left((1-\frac{1}{v})\hat{f}_{j+1}^n + (1+\frac{1}{v})\hat{f}_{j}^n \right)$

# %% [markdown]
# where $v = c\cdot \frac{\Delta t}{\Delta x}$

# %% [markdown]
# Lax-Wendroff method
#
# $\hat{f}_{j+\frac{1}{2}}^n =\frac{1}{2} \left((1-v)\hat{f}_{j+1}^n + (1+v)\hat{f}_{j}^n \right)$

# %% [markdown]
# #### Reconstruct by flux

# %%
dt = 0.05
dx = 0.1
jmax = 21
nmax = 6

# %%
def init(q1,q2,dx,jmax):
    x = np.linspace(0,dx * (jmax -1),jmax)
    q = np.array([(float(q1) if i < 0.5 * jmax else float(q2) ) for i in range (jmax)])
    return (x,q)

# %%
# FTCS
def FTCS(q,c,dt,dx,j):
    return 0.5 * c * (q[j+1]+q[j])
# Upwind1
def upwind(q,c,dt,dx,j):
    return c * q[j]
# Lax
def lax(q,c,dt,dx,j):
    nv = 1 / (c * dt / dx)
    return 0.5 * c * ((1-nv) * q[j+1] + (1+nv) * q[j])
# LW
def laxwen(q,c,dt,dx,j):
    nv1 = c * dt / dx
    return 0.5 * c * ((1-nv1) * q[j+1] + (1+nv1) * q[j])

# %%
def do_compute(x,q,c,dt,nmax,dx,ff):
    plt.figure(figsize=(7,7),dpi=100)
    plt.rcParams["font.size"] = 22
    plt.plot(x,q,marker="o",lw=2,label="n=0")

    for n in range (1, 7):
        qold = q.copy()
        for j in range(1,jmax -1):
            ff1 = ff(qold,c,dt,dx,j)
            ff2 = ff(qold,c,dt,dx,j-1)
            q[j] = qold[j] - dt / dx * (ff1-ff2)
        
        if n %2 ==0:
            plt.plot(x,q,marker="o",lw=2,label=f'n={n}')
    plt.grid(color="black",linestyle="dashed",linewidth=0.5)
    plt.xlim([0,2])
    plt.xlabel("x")
    plt.ylabel("q")
    plt.legend()
    plt.title(f"{ff.__name__}")
    plt.show()

# %%
c = 1
q1, q2 = 1, 0
x,q = init(q1,q2,dx,jmax)

# %%
do_compute(x,q,c,dt,dx,nmax,FTCS)

# %%
do_compute(x,q,c,dt,dx,nmax,upwind)

# %%
do_compute(x,q,c,dt,dx,nmax,lax)

# %%
do_compute(x,q,c,dt,dx,nmax,laxwen)

# %% [markdown]
# ## 2.5 Numerical flux and the idea of higher-order accuracy.

# %% [markdown]
# ### 2.5.1 If the direction of information propagation is known (c >0)

# %% [markdown]
# Review:
#
# $\frac{\partial q}{\partial t} + c \frac{\partial q}{\partial x} = 0  \ (c>0)$

# %% [markdown]
# a second-order accurate:
#
# $q_{j}^{n+1} = q_{j}^{n} - \frac{\Delta t \cdot c \cdot (3q_j^n - 3q_{j-1}^n + q_{j-2}^n)}{\Delta 2x} $
#
# $q_{j}^{n+1} = q_{j}^{n} - \frac{\Delta t \cdot c}{\Delta x} \left((\frac{3}{2}q_j^n - \frac{1}{2}q_{j-1}^n) - (\frac{3}{2}q_{j-1}^n - \frac{1}{2}q_{j-2}^n) \right)$

# %% [markdown]
# Review:
#
# $q_{j}^{n+1} = q_{j}^{n} - \frac{\Delta t}{\Delta x} (\hat{f}_{j + \frac{1}{2}}^n -\hat{f}_{j - \frac{1}{2}}^n)$
#
# $\begin{cases} \hat{f}_{j + \frac{1}{2}}^n = f_j^n \text{(1st accurate)}\\\hat{f}_{j + \frac{1}{2}}^n =  \frac{3}{2}f_j^n  - \frac {1}{2} f_{j-1}^n \text{(2nd accurate)}\end{cases}$

# %% [markdown]
# ### 2.5.2 If the direction of information propagation is unknown (c < 0)

# %% [markdown]
# $\hat{f}_{j + \frac{1}{2}}^n = \frac{1}{2} [(f_R + f_L) - |c|(q_R -q_L)]$

# %% [markdown]
# $\begin{cases} f_R = f_{j+1}^n, f_L = f_j^n \text{(1)}\\
# f_R = \frac{3}{2}f_{j+1}^n - \frac{1}{2}f_{j+2}^n , f_L = \frac{3}{2}f_{j}^n - \frac{1}{2}f_{j-1}^n \end{cases}$

# %%
def init(q1, q2,dx,jmax):
    x = np.linspace(0,dx*(jmax -1),jmax)
    q = np.array([(float(q1) if i < 0.5 * jmax else float(q2)) for i in range(jmax)])
    return(x,q)
def UPWIND1(q,c,dt,dx,j):
    ur = q[j+1]
    ul = q[j]
    fr = c * ur
    fl = c * ul
    return 0.5 * (fr + fl -abs(c) * (ur - ul))
def UPWIND2(q,c,dt,dx,j):
    ur = 1.5 * q[j+1] - 0.5 * q[j+2]
    ul = 1.5 * q[j] - 0.5 * q[j-1]
    fr = c * ur
    fl = c * ul
    return 0.5 * (fr + fl -abs(c) * (ur - ul))
def do_computing(x,q,c,dt,dx,nmax,ff,order =1,interval = 2,ylim = None,yticks = None):
    plt.figure(figsize=(7,7),dpi=100)
    plt.rcParams["font.size"] = 22
    plt.plot(x,q,marker="o",lw=2,label="n=0")

    for n in range (1, nmax+1):
        qold = q.copy()
        for j in range(order,jmax -order):
            ff1 = ff(qold,c,dt,dx,j)
            ff2 = ff(qold,c,dt,dx,j-1)
            q[j] = qold[j] - dt / dx * (ff1-ff2)
        
        if n % interval ==0:
            plt.plot(x,q,marker="o",lw=2,label=f'n={n}')
            
    plt.grid(color="black",linestyle="dashed",linewidth=0.5)
    plt.xlabel("x")
    plt.ylabel("q")
    plt.legend()
    if ylim is not None:
        plt.ylim(ylim)
    if yticks is not None:
        plt.yticks(yticks)
    plt.show()

# %%
c =  1
dt = 0.05
dx = 0.1
jmax = 21
nmax = 6
q1 = 1
q2 = 0
x,q = init(q1,q2,dx,jmax)

do_computing(x,q,c,dt,dx,nmax,UPWIND1,order=1,interval=2)

# %%
c =  -1
dt = 0.05
dx = 0.1
jmax = 21
nmax = 6
q1 = 1
q2 = 0
x,q = init(q1,q2,dx,jmax)

do_computing(x,q,c,dt,dx,nmax,UPWIND1,order=1,interval=2)

# %%
c =  1
dt = 0.05
dx = 0.1

jmax = 21
nmax = 6

q1 = 1
q2 = 0
x,q = init(q1,q2,dx,jmax)

do_computing(x,q,c,dt,dx,nmax,UPWIND2,order=2,interval=2)

# %%
c =  -1
dt = 0.05
dx = 0.1

jmax = 21
nmax = 6

q1 = 0
q2 = 1
x,q = init(q1,q2,dx,jmax)

do_computing(x,q,c,dt,dx,nmax,UPWIND2,order=2,interval=2)

# %% [markdown]
# ## 2.6 A nonlinear transport problem involving unknowns

# %% [markdown]
# ### Basic method for solving the Burgers equation 1

# %% [markdown]
# Review:
#
# $\frac{\partial q}{\partial t} + q \frac{\partial q}{\partial x} = 0 $

# %% [markdown]
# $\frac{\partial q}{\partial t} + \frac{\partial}{\partial x}(\frac{1}{2}q^2) = 0 $

# %% [markdown]
# #### Merman-Cola Method

# %% [markdown]
# $q_j^{n+1} = q_j^n - \frac{\Delta t}{\Delta x} \frac{q_{j}^{n} + q_{j-1}^{n}}{2} (q_{j}^{n} - q_{j-1}^{n})$

# %% [markdown]
# $q_j^{n+1} = q_j^n - \frac{\Delta t}{\Delta x} \frac{q_{j+1}^{n} + q_{j}^{n}}{2} (q_{j+1}^{n} - q_{j}^{n})$

# %%
def init(q1, q2,dx,jmax):
    xs = -1.0
    x = np.linspace(xs,xs + dx*(jmax -1),jmax)
    q = np.array([(float(q1) if i < 0.0 else float(q2)) for i in x])
    return(x,q)

def do_computeMC(x,q,dt,dx,nmax,ff,order =1,interval = 2):
    plt.figure(figsize=(7,7),dpi=100)
    plt.rcParams["font.size"] = 22
    plt.plot(x,q,marker="o",lw=2,label="n=0")

    for n in range (1, nmax + 1):
        qold = q.copy()
        for j in range(order,jmax -order):
            ff1 = ff(qold,qold[j],dt,dx,j)
            ff2 = ff(qold,qold[j],dt,dx,j-1)
            q[j] = qold[j] - dt / dx * (ff1-ff2)
        
        if n % interval ==0:
            plt.plot(x,q,marker="o",lw=2,label=f'n={n}')
            
    plt.grid(color="black",linestyle="dashed",linewidth=0.5)
    plt.xlabel("x")
    plt.ylabel("q")
    plt.legend()
    plt.title(f"$q_1$:{q1}$q_2$:{q2}")
    plt.show()

def MC(q,c,dt,dx,j):
    ur = q[j+1]
    ul = q[j]
    fr = 0.5 * ur**2
    fl = 0.5 * ul**2
    c = 0.5 * (ur + ul)
    return 0.5 * (fr + fl - np.sign(c) * (fr - fl))

q1 = 2
q2 = 1
x,q = init(q1,q2,dx,jmax)
namx = 20
do_computeMC(x,q,dt,dx,nmax,MC,interval=2)

# %%
dt = 0.05
dx = 0.1

jmax = 21
nmax = 6

q1 = 2
q2 = 1
x,q = init(q1,q2,dx,jmax)
do_computeMC(x,q,dt,dx,nmax,MC,interval=2)

# %%
q1 = 1
q2 = 2
x,q = init(q1,q2,dx,jmax)
do_computeMC(x,q,dt,dx,nmax,MC,interval=2)

# %%
q1 = 1
q2 = -1
x,q = init(q1,q2,dx,jmax)
do_computeMC(x,q,dt,dx,nmax,MC,interval=2)

# %%
q1 = -1
q2 = 1
x,q = init(q1,q2,dx,jmax)
do_computeMC(x,q,dt,dx,nmax,MC,interval=2)

# %% [markdown]
# ### Basic method for solving the Burgers equation 2

# %% [markdown]
# $\frac{\partial q}{\partial t} + \frac{\partial}{\partial x}(\frac{1}{2}q^2) = 0 $

# %% [markdown]
# $\lambda = \frac{\partial f}{\partial q} = q$

# %% [markdown]
# $S = \frac{\Delta f}{\Delta q}$

# %% [markdown]
# $\int (\rho dx - f dt ) =0$

# %% [markdown]
# #### Godunov Method

# %% [markdown]
# $\hat{f}_{j+\frac{1}{2}} = \begin{cases} \frac{1}{2}q_{j+1}^2 &q_j,q_{j+1} < 0 \\ \frac{1}{2}q_{j}^2 &q_j,q_{j+1} > 0 \end{cases}$

# %% [markdown]
# $\hat{f}_{j+\frac{1}{2}} = \begin{cases} \frac{1}{2}q_{j+1}^2 &q_j > 0 > q_{j+1} & c_{j+\frac{1}{2}} = \frac{q_j +q_{j+1}}{2}<0\\ \frac{1}{2}q_{j}^2 &q_j > 0 > q_{j+1} & c_{j+\frac{1}{2}} = \frac{q_j +q_{j+1}}{2}>0 \\0 & q_j<0<q_{j+1}\end{cases}$

# %%
def GODUNOVa(q,c,dt,dx,j):
    ur = q[j+1]
    ul = q[j]
    fr = 0.5 *ur**2
    fl = 0.5 *ul**2
    c = 0.5 * (ur +ul)

    if q[j] <= 0 and q[j+1] <=0:
        return fr
    elif q[j] >= 0 and q[j+1]>=0:
        return fl
    elif q[j]>0>q[j+1]:
        if c< 0 :
            return fr
        else:
            return fl
    else :
        return 0

# %%
def GODUNOVb(q,c,dt,tx,j):
    qm = 0.5 * (q[j] + np.abs(q[j]))
    qp = 0.5 * (q[j+1]- np.abs(q[j+1]))
    return np.max([0.5 * qm**2,0.5 * qp**2])

# %%
dt = 0.05
dx = 0.1

jmax = 21
nmax = 10

q1 = 2
q2 = 1
x,q = init(q1,q2,dx,jmax)

do_computeMC(x,q,dt,dx,nmax,GODUNOVa)

# %%
dt = 0.05
dx = 0.1

jmax = 21
nmax = 10

q1 = 2
q2 = 1
x,q = init(q1,q2,dx,jmax)

do_computeMC(x,q,dt,dx,nmax,GODUNOVb)

# %% [markdown]
# ## 2.7 Expending to multi-dimension

# %% [markdown]
# $\frac{\partial q}{\partial t} + c \frac{\partial q}{\partial x}+ d \frac{\partial q}{\partial y} = 0 $

# %%
from mpl_toolkits.mplot3d import axes3d

# %%
c = 1
d = 1
dy = 0.1

jmax = 41
kmax = 41
nmax = 30

# %%
def init(dx,dy,jmax,kmax):
    x = np.linspace(0,dx * (jmax -1),jmax)
    y = np.linspace(0,dy * (kmax -1),kmax)
    q = init_q(x,y,jmax,kmax)
    return(x,y,q)

# %%
def init_q(x,y,jmax,kmax):
    def gausfunc(x,y,mu,V):
        detV = np.linalg.det(V)
        invV = np.linalg.inv(V)
        A = 1.0 / (2 * np.pi *np.sqrt(detV))
        dX = (np.array([x,y])- mu[:,None,None]).transpose(1,2,0)
        return A * np.exp( - 0.5 * dX[:,:,None] @invV[None,None]@dX[:,:,:,None])
    mu = np.array([dx * jmax / 4 ,dy * kmax / 4])
    V = np.array([[dx*jmax / 40,0],[0,dy*kmax / 40]])
    X,Y = np.meshgrid(x,y)
    q = gausfunc(X,Y,mu,V)[:,:,0,0]
    return q

def do_compute3D(x,y,q,dt,dx,dy,nmax,interval =2):
    X,Y = np.meshgrid(x,y)
    
    fig = plt.figure(figsize=(10,7), dpi=100)
    plt.rcParams["font.size"] = 10

    ax1 = fig.add_subplot(1,1,1,projection ="3d")
    ax1.plot_wireframe(X,Y,q,color ="black",rstride =1,cstride =1, linewidth = 0.5)
    ax1.set_xlabel("x")
    ax1.set_ylabel("y")

    for n in range (1, nmax + 1):
        qold = q.copy()
        for j in range(1,jmax -1):
            for k in range(1,kmax -1):
                q[j][k] = qold[j][k]- dt /dx*(
                    c * (qold[j][k]-qold[j-1][k]) + d * (qold[j][k] - qold[j][k-1])
                )        
        if n % interval ==0:
            ax1.plot_wireframe(X,Y,q,color="black",rstride=1,cstride=1,linewidth=0.5)
            
    plt.show()

x,y,q = init(dx,dt,jmax,kmax)
do_compute3D(x,y,q,dt,dx,dy,nmax,interval=10)

# %% [markdown]
# ## 2.8 Practical numerical methods

# %%
def init(q1,q2,dx,jmax,sp = 0.5):
    x = np.linspace(0,dx * (jmax -1),jmax)
    q = np.array([float(q1) if i < sp * jmax else float(q2) for i in range (jmax)])
    return (x,q)
def minmod(x,y):
    sgn = np.sign(x)
    return sgn * max(min(abs(x),sgn * y),0.0)
def do_compute2(x,q,c,dt,dx,nmax,ff,interval=2):
    plt.figure(figsize=(7,7),dpi=100)
    plt.rcParams["font.size"] = 22
    plt.plot(x,q,marker="o",lw=2,label="n=0")

    delta = np.zeros(jmax)
    g = np.zeros(jmax)
    flux = np.zeros(jmax)

    for n in range(1,jmax -1):
        qold = q.copy()

        for j in range(0,jmax-1):
            delta[j] = qold[j+1] - qold[j]
        for j in range(1,jmax -1):
            g[j] = minmod(delta[j],delta[j-1])
        for j in range(0,jmax-1):
            flux[j] = ff(qold,c,delta,g,dt,dx,j)
        for j in range(1,jmax-1):
            q[j] = qold[j] - dt / dx * (flux[j]-flux[j-1])
        if n % interval ==0:
            plt.plot(x,q,marker="o",lw=2,label=f'n={n}')
            
    plt.grid(color="black",linestyle="dashed",linewidth=0.5)
    plt.xlabel("x")
    plt.ylabel("q")
    plt.legend()
    plt.show()

# %%
def TVD(q,c,delta,g,dt,dx,j):
    sigma = 0.5 * (np.abs(c) - dt/dx*c**2)
    gamma = sigma*(g[j+1]-g[j])*delta[j] / (delta[j]**2 + 1e-12)
    phi = sigma * (g[j]+g[j+1]) - abs(c + gamma) * delta[j]

    ur = q[j+1]
    ul = q[j]
    fr = c *ur
    fl = c * ul
    return 0.5 * (fl+fr +phi)
c = 1
dt = 0.05
dx = 0.1
jmax = 21
nmax = 20
q1 = 1
q2 = 0
x,q = init(q1,q2,dx,jmax,sp=0.05)
do_compute2(x,q,c,dt,dx,nmax,TVD,interval=4)
